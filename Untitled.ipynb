# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
from pathlib import Path
from read_roi import read_roi_zip
from collections import OrderedDict, Counter
import math
import PIL
from PIL import Image
from PIL.TiffTags import TAGS
import tkinter as tk
from tkinter import filedialog
import seaborn as sns
from pandas.api.types import CategoricalDtype
import itertools
from colour import Color
from datetime import date

# %%
today = date.today()
print("Today's date:", today)
date = str(today)
date
# Out:
# Today's date: 2021-11-17
# '2021-11-17'

# %%
askdirectory = filedialog.askdirectory() # show an "Open" dialog box and return the path to the selected file
path = Path(askdirectory)
path
# Out:
# WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips')

# %%
dateloc = str(path).find("202")
date = str(path)[dateloc : dateloc+10]

folders = [x for x in path.iterdir() if x.is_dir()]
folders = [i for i in folders if (str(i)[-3:] == 'yes') == True]
date,folders
# Out:
# ('2021-11-15',
#  [WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH3_DCXGFP01nM_typeWT_DCXRFP07nM-yes'),
#   WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH6_DCXGFP01nM_typeR303X_DCXRFP07nM-yes'),
#   WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH7_DCXGFP01nM_typeWT_DCXRFP07nM-yes')])

# %%
files = []
for j in range(0,len(folders)):  
    resultfolder = folders[j]/'cropped-results'
    files0 = [x for x in resultfolder.iterdir() if x.is_file()]
    files0 = [i for i in files0 if str(i).rfind('Results-Area') != -1]
    files = files + files0
files
# Out:
# [WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH3_DCXGFP01nM_typeWT_DCXRFP07nM-yes/cropped-results/1_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH3_DCXGFP01nM_typeWT_DCXRFP07nM-yes/cropped-results/2_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH3_DCXGFP01nM_typeWT_DCXRFP07nM-yes/cropped-results/3_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH3_DCXGFP01nM_typeWT_DCXRFP07nM-yes/cropped-results/4_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH3_DCXGFP01nM_typeWT_DCXRFP07nM-yes/cropped-results/6_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH6_DCXGFP01nM_typeR303X_DCXRFP07nM-yes/cropped-results/10_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH6_DCXGFP01nM_typeR303X_DCXRFP07nM-yes/cropped-results/1_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH6_DCXGFP01nM_typeR303X_DCXRFP07nM-yes/cropped-results/2_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH6_DCXGFP01nM_typeR303X_DCXRFP07nM-yes/cropped-results/3_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH6_DCXGFP01nM_typeR303X_DCXRFP07nM-yes/cropped-results/8_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH6_DCXGFP01nM_typeR303X_DCXRFP07nM-yes/cropped-results/9_Results-Area.csv'),
#  WindowsPath('C:/Users/sofia/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips/CH7_DCXGFP01nM_typeWT_DCXRFP07nM-yes/cropped-results/3_Results-Area.csv')]

# %%
ch = []
conc_DCXRFP = []
conc_DCXGFP = []
DCX_type = []

for i in files:
    CHloc = str(i).find('CH')
    DCXRFPloc = str(i).rfind('RFP')
    DCXGFPloc = str(i).rfind('GFP')
    dcxtype = str(i).find('type')
    ch = ch + [str(i)[CHloc+2:CHloc+3]]
    conc_DCXRFP = conc_DCXRFP + [(str(i)[DCXRFPloc+3:DCXRFPloc+5])]
    conc_DCXGFP = conc_DCXGFP + [(str(i)[DCXGFPloc+3:DCXGFPloc+5])]
    DCX_type = DCX_type + [(str(i)[dcxtype+4:DCXRFPloc-4])]

    conc_DCXGFP =  [float(i) for i in conc_DCXGFP]
    conc_DCXRFP =  [float(i) for i in conc_DCXRFP]

# %%
metadf = pd.DataFrame({'CH': ch,'Type': DCX_type,
                   '[GFP-DCX]': conc_DCXGFP,
                   '[RFP-DCX]': conc_DCXRFP})

# %%
df = pd.DataFrame(columns=['GFP','RFP','Cy5','GFPxRFP'])
for i in files:
    resultcsv = pd.read_csv(i, encoding='utf-8')
    arr = resultcsv['Mean'].values
    df = df.append(pd.DataFrame(arr.reshape(1,-1), columns=list(df)), ignore_index=True)

# %%
result = pd.concat([metadf, df], axis=1)
result
# Out:
#    CH   Type  [GFP-DCX]  [RFP-DCX]    GFP    RFP     Cy5  GFPxRFP
# 0   3     WT        1.0        7.0  5.295  6.168  18.316    3.767
# 1   3     WT        1.0        7.0  5.162  6.107  17.543    3.735
# 2   3     WT        1.0        7.0  3.299  5.817  16.743    2.654
# 3   3     WT        1.0        7.0  3.155  4.237  12.526    2.312
# 4   3     WT        1.0        7.0  2.675  3.910  11.876    1.933
# 5   6  R303X        1.0        7.0  2.507  5.072  21.602    1.785
# 6   6  R303X        1.0        7.0  4.286  5.218  15.241    2.785
# 7   6  R303X        1.0        7.0  2.567  3.811  18.649    1.331
# 8   6  R303X        1.0        7.0  6.397  8.158  31.807    4.030
# 9   6  R303X        1.0        7.0  3.548  7.421  30.499    2.782
# 10  6  R303X        1.0        7.0  1.568  3.636  19.645    1.045
# 11  7     WT        1.0        7.0  5.020  7.294  17.636    4.039

# %%
corr_gfp = '% Correlation GFP'
area_rfp = 'RFP Area %'
Type = 'Type'

result[corr_gfp] = df['GFPxRFP'] / df['GFP'] * 100
result[area_rfp] = df['RFP'] / df['Cy5'] * 100
result
# Out:
#    CH   Type  [GFP-DCX]  [RFP-DCX]    GFP    RFP     Cy5  GFPxRFP  \
# 0   3     WT        1.0        7.0  5.295  6.168  18.316    3.767
# 1   3     WT        1.0        7.0  5.162  6.107  17.543    3.735
# 2   3     WT        1.0        7.0  3.299  5.817  16.743    2.654
# 3   3     WT        1.0        7.0  3.155  4.237  12.526    2.312
# 4   3     WT        1.0        7.0  2.675  3.910  11.876    1.933
# 5   6  R303X        1.0        7.0  2.507  5.072  21.602    1.785
# 6   6  R303X        1.0        7.0  4.286  5.218  15.241    2.785
# 7   6  R303X        1.0        7.0  2.567  3.811  18.649    1.331
# 8   6  R303X        1.0        7.0  6.397  8.158  31.807    4.030
# 9   6  R303X        1.0        7.0  3.548  7.421  30.499    2.782
# 10  6  R303X        1.0        7.0  1.568  3.636  19.645    1.045
# 11  7     WT        1.0        7.0  5.020  7.294  17.636    4.039
#
#     % Correlation GFP  RFP Area %
# 0           71.142587   33.675475
# 1           72.355676   34.811606
# 2           80.448621   34.742878
# 3           73.280507   33.825643
# 4           72.261682   32.923543
# 5           71.200638   23.479307
# 6           64.979001   34.236599
# 7           51.850409   20.435412
# 8           62.998280   25.648442
# 9           78.410372   24.331945
# 10          66.645408   18.508526
# 11          80.458167   41.358585

# %%
fig, axs = plt.subplots(1,1,figsize=(5,5))
sns.set_style("ticks")

ax = sns.swarmplot(x=Type, y=corr_gfp, data=result)
ax.set(ylim=(0, 100))

sns.despine()
sns.set_context("poster", font_scale=1, rc={"lines.linewidth":3.0})
plt.tight_layout()

# %%
fig, axs = plt.subplots(1,1,figsize=(5,5))
sns.set_style("ticks")

ax = sns.swarmplot(x=Type, y=area_rfp, data=result)
ax.set(ylim=(0, 100))

sns.despine()
sns.set_context("poster", font_scale=1, rc={"lines.linewidth":3.0})
plt.tight_layout()
