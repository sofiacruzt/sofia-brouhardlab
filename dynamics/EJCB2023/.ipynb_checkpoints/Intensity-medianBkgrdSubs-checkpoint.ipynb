# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import pandas as pd
from pandas.api.types import CategoricalDtype
import scipy as sp
from pathlib import Path
from tkinter import filedialog
import itertools
#from colour import Color
from datetime import date
# import statsmodels.api as sm
# from statsmodels.stats.weightstats import ztest as ztest
#from sklearn.metrics import r2_score as R2S
import cairo
import lmfit

# %% [markdown]
# ## Names and Palette ##

# %%
today = date.today()
print("Today's date:", today)
date = str(today)
date
# Out:
# Today's date: 2023-10-17
# '2023-10-17'

# %%
tubulin = '[Tubulin] ' r'$(\mu M)$'
tub = 'tub'

DCXconc = '[DCX] ' r'$(n M)$'
EBconc = '[EB] ' r'$(n M)$'
DCX = 'DCX'
Type = 'DCX Type'

Concentration = 'Concentration ' r'$(\mu M)$'
Length = 'Length ' r'$(\mu m)$'
Lifetime = 'Lifetime ' r'$(min)$'
GrowthRate = 'Growth Rate ' r'$(\mu m / min)$'
TimeToNucleate = 'Time to Nucleate ' r'$(min)$'
ShrinkageLength = 'Shrink Length ' r'$(\mu m)$'
ShrinkageLifetime = 'Shrink Lifetime ' r'$(min)$'
ShrinkageRate = 'Shrink Rate ' r'$(\mu m / min)$'

# %% [markdown]
# ## Join Data ##

# %%
askdirectory = filedialog.askdirectory() # show an "Open" dialog box and return the path to the selected file
path = Path(askdirectory)

# %%
folders = [x for x in path.iterdir() if x.is_dir()]
folders = [i for i in folders if str(i.stem)[-1] == 'M']
folders
# Out:
# [WindowsPath('D:/Sofia/2023_2summer-fall_DCXintensitydynmts/2023-10-16_nonSEC-dcxdynWT/CH1_typeWT_DCX230nM'),
#  WindowsPath('D:/Sofia/2023_2summer-fall_DCXintensitydynmts/2023-10-16_nonSEC-dcxdynWT/CH4_typeWT_DCX500nM')]

# %%
files = []
for k in folders:
    files0 = [x for x in k.iterdir() if x.is_file()]
    files0 = [i for i in files0 if str(i).rfind('Results_') != -1 if str(i).rfind('csv') != -1]
    files = files + files0
files
# Out:
# [WindowsPath('D:/Sofia/2023_2summer-fall_DCXintensitydynmts/2023-10-16_nonSEC-dcxdynWT/CH1_typeWT_DCX230nM/Results_processed.csv'),
#  WindowsPath('D:/Sofia/2023_2summer-fall_DCXintensitydynmts/2023-10-16_nonSEC-dcxdynWT/CH4_typeWT_DCX500nM/Results_processed.csv')]

# %%
def findmetadata(tag,end,i):
    n = len(tag)
    locstart = str(i).rfind(tag) 
    locend = str(i).find(end, locstart)
    tag0 = str(i)[locstart+n: locend]
    
    return tag0

# %%
dates= []
CH= []
dcx = []
dcxtype= []
for i in files:
    dateloc = str(i).rfind("202")   
    dates0 = str(i)[dateloc : dateloc+10]
    dates = dates + [dates0]

    CH0 = findmetadata("CH",'_',i)
    CH = CH + [CH0]  
    
    type0 = findmetadata("type",'_',i)
    dcxtype = dcxtype + [type0] 
    
    dcx0 = findmetadata("DCX",'nM',i)
    dcx = dcx + [float(dcx0)] 

dates,CH,dcx, dcxtype
# Out:
# (['2023-10-16', '2023-10-16'], ['1', '4'], [230.0, 500.0], ['WT', 'WT'])

# %% [markdown]
# ## Open Data ##

# %%
data = pd.DataFrame(columns=[] , index=[])

for i in np.arange(len(files)):
    data0 = pd.read_csv(files[i], encoding='utf-8',keep_default_na=False)

    
    data0['Date'] = dates[i]
    data0['CH'] = CH[i]
    data0[DCXconc] = dcx[i]
    data0['Type'] = dcxtype[i]
    
    data = pd.concat([data,data0], ignore_index=True)

data = data.rename(columns={"Mean": "Intensity"})
data = data.sort_values(by = DCXconc)
data
# Out:
#         Area  Intensity  Min  Max    Angle   Length        Date CH  \
# 0    1   746     56.763    8   83 -169.970  149.282  2023-10-16  1
# 13  14   216     23.051    7   35  -65.225   42.953  2023-10-16  1
# 12  13   150     27.767   13   41 -158.552   30.083  2023-10-16  1
# 11  12   542     33.253   12   47  154.855  108.259  2023-10-16  1
# 9   10   534     38.361   12   55  -15.208  106.738  2023-10-16  1
# 8    9   312     36.449   20   48 -176.309   62.129  2023-10-16  1
# 7    8   276     29.975   11   43  175.840   55.145  2023-10-16  1
# 10  11   530     32.719   10   49 -169.216  106.888  2023-10-16  1
# 5    6   160     44.600   14   73   -7.125   32.249  2023-10-16  1
# 4    5   477     31.327   14   52  -72.324   95.509  2023-10-16  1
# 3    4   302     34.904   13   49   59.199   60.539  2023-10-16  1
# 2    3   410     35.980   11   48   -1.397   82.024  2023-10-16  1
# 1    2   432     33.380   16   44  100.660   86.493  2023-10-16  1
# 6    7   356     43.885   18   60  178.386   71.028  2023-10-16  1
# 24  11   106     45.330   22   80  -95.440   21.095  2023-10-16  4
# 30  17   118     53.136   33   75  -53.616   23.601  2023-10-16  4
# 29  16   238     31.971   11   50  -59.657   47.508  2023-10-16  4
# 28  15   196     33.327   12   51  -95.856   39.205  2023-10-16  4
# 27  14   240     40.071   20   54   -7.125   48.374  2023-10-16  4
# 26  13   232     41.392   12   66   59.036   46.648  2023-10-16  4
# 25  12   252     37.762    9   55  110.956   50.329  2023-10-16  4
# 23  10   260     42.615   11   64 -101.094   51.971  2023-10-16  4
# 16   3   319     74.834   32  130   30.964   64.140  2023-10-16  4
# 21   8   300     48.680   19   77  170.538   60.828  2023-10-16  4
# 20   7   138     45.804    7   74 -109.093   27.514  2023-10-16  4
# 19   6   336     47.542   18   65  178.290   67.030  2023-10-16  4
# 18   5   244     52.939   25   88 -135.830   48.795  2023-10-16  4
# 17   4   180     62.033   41   87  -90.000   36.000  2023-10-16  4
# 31  18   128     69.617   38  108  -67.380   26.000  2023-10-16  4
# 15   2   185     59.838   35   84  -90.000   37.000  2023-10-16  4
# 14   1   378     58.413   27   80   69.887   75.611  2023-10-16  4
# 22   9   301     52.718   28   79   79.439   60.017  2023-10-16  4
# 32  19   110     51.082   14   78  140.528   22.023  2023-10-16  4
#
#     [DCX] $(n M)$ Type
# 0           230.0   WT
# 13          230.0   WT
# 12          230.0   WT
# 11          230.0   WT
# 9           230.0   WT
# 8           230.0   WT
# 7           230.0   WT
# 10          230.0   WT
# 5           230.0   WT
# 4           230.0   WT
# 3           230.0   WT
# 2           230.0   WT
# 1           230.0   WT
# 6           230.0   WT
# 24          500.0   WT
# 30          500.0   WT
# 29          500.0   WT
# 28          500.0   WT
# 27          500.0   WT
# 26          500.0   WT
# 25          500.0   WT
# 23          500.0   WT
# 16          500.0   WT
# 21          500.0   WT
# 20          500.0   WT
# 19          500.0   WT
# 18          500.0   WT
# 17          500.0   WT
# 31          500.0   WT
# 15          500.0   WT
# 14          500.0   WT
# 22          500.0   WT
# 32          500.0   WT

# %%
newdirectory = str(path.parents[0])+'//Intensity_Data_Sheets'
newmydir = Path(newdirectory)
newmydir.mkdir(exist_ok=True)
newmydir
# Out:
# WindowsPath('D:/Sofia/2023_2summer-fall_DCXintensitydynmts/Intensity_Data_Sheets')

# %%
name = dates[0]+'_Intensity_analysed-on_'+date +'.csv'
name
# Out:
# '2023-10-16_Intensity_analysed-on_2023-10-17.csv'

# %%
data.to_csv(path/(name), encoding='utf-8', index=False)
data.to_csv(newmydir/(name), encoding='utf-8', index=False)

# %% [markdown]
# ## Open prev sevad data ##

# %%
askFitParam = filedialog.askopenfilename() # show an "Open" dialog box and return the path to the selected file
data = pd.read_csv(askFitParam, encoding='utf-8',keep_default_na=False)
data
# Out:
#          Area  Intensity  Min  Max    Angle  Length        Date  CH  \
# 0     8   130     15.946    3   29  -62.447  25.942  2023-10-04   8
# 1     1   265     25.411   10   38  -88.919  53.009  2023-10-04   4
# 2     2   112     23.259    9   38  144.162  22.204  2023-10-04   4
# 3     4   143     20.867    5   33   36.469  28.601  2023-10-04   4
# 4     5   240     22.913    2   38  153.435  44.721  2023-10-04   4
# ..   ..   ...        ...  ...  ...      ...     ...         ...  ..
# 483  18   128     69.617   38  108  -67.380  26.000  2023-10-16   4
# 484   2   185     59.838   35   84  -90.000  37.000  2023-10-16   4
# 485   1   378     58.413   27   80   69.887  75.611  2023-10-16   4
# 486   9   301     52.718   28   79   79.439  60.017  2023-10-16   4
# 487  19   110     51.082   14   78  140.528  22.023  2023-10-16   4
#
#      [DCX] $(n M)$ Type
# 0               30   WT
# 1               30   WT
# 2               30   WT
# 3               30   WT
# 4               30   WT
# ..             ...  ...
# 483            500   WT
# 484            500   WT
# 485            500   WT
# 486            500   WT
# 487            500   WT
#
# [488 rows x 11 columns]

# %% [markdown]
# ## Plot ##

# %%
grey00 = '#777777'
grey20 = '#C5C5C5'

# %%
fig, ax = plt.subplots(1,1,figsize=(17,12))

# ax = sns.boxplot(x= DCXconc, y='Mean', data=data, whis=np.inf,linewidth=3,native_scale=True)
# ax = sns.swarmplot(x=DCXconc, y='Mean', data=data, hue='Date', size=5,native_scale=True , palette = [grey00, grey20])

ax = sns.boxplot(x= DCXconc, y='Intensity', data=data, whis=np.inf,linewidth=3,native_scale=True)
ax = sns.swarmplot(x=DCXconc, y='Intensity', data=data, hue='Date', size=6,native_scale=True , palette = 'hls')

#ax.legend( loc = 'lower right')
#ax.legend('')
ax.set_xlabel(DCXconc)

ax.set_xlim(0,550) 
ax.set_ylim(0,100) 
# ax.set_xticks(np.arange(0, 251, 50))
sns.set_style("ticks")
sns.despine()
ax.spines['left'].set_lw(5)
ax.spines['bottom'].set_lw(5)
ax.tick_params(axis='both', width = 5, length = 15)
sns.set_context("poster", font_scale=1.7, rc={"lines.linewidth":3.0})

plt.tight_layout()


plt.savefig(newmydir/('intensity_'+date+'.svg'),backend='Cairo')
plt.savefig(newmydir/('intensity_'+date+'.png'),backend='Cairo')
# Out:
# C:\Users\Brouhard Lab\anaconda3\envs\brouhardlab-env\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 53.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Brouhard Lab\anaconda3\envs\brouhardlab-env\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Brouhard Lab\anaconda3\envs\brouhardlab-env\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 9.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Brouhard Lab\anaconda3\envs\brouhardlab-env\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Brouhard Lab\anaconda3\envs\brouhardlab-env\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Brouhard Lab\anaconda3\envs\brouhardlab-env\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 18.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Brouhard Lab\anaconda3\envs\brouhardlab-env\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 8.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Brouhard Lab\anaconda3\envs\brouhardlab-env\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Brouhard Lab\anaconda3\envs\brouhardlab-env\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
datamean = data.groupby(by=DCXconc)[["Intensity", DCXconc]].mean()
datastd = data.groupby(by=DCXconc)[["Intensity", DCXconc]].std()

# %%
datamean
# Out:
#                Intensity  [DCX] $(n M)$
# [DCX] $(n M)$
# 5               0.992615            5.0
# 30             17.765138           30.0
# 60             23.234559           60.0
# 80             26.608397           80.0
# 115            36.465775          115.0
# 230            42.496069          230.0
# 500            39.874810          500.0

# %%
x = datamean[DCXconc].values
y = datamean['Intensity'].values
yerr = datastd['Intensity'].values

# %%
def hillEQ(x, n, kd):
    return  (y[-1]) * np.power(x, n)/(kd + np.power(x, n))
    
def MMEQ(x, kd):
    return  (y[-1]) * np.power(x, 1)/(kd + np.power(x, 1))

# %%
coeffH, var_matrixH = sp.optimize.curve_fit(hillEQ,x,y)

varianceH = np.diagonal(var_matrixH) #Refer [3]
SEH = np.sqrt(varianceH)
C1H, C2H = coeffH
coeffH,SEH
# Out:
# (array([  1.63431547, 427.91112643]), array([3.93153698e-01, 6.79460271e+02]))

# %%
coeffM, var_matrixM = sp.optimize.curve_fit(MMEQ,x,y)

varianceM = np.diagonal(var_matrixM) #Refer [3]
SEM = np.sqrt(varianceM)
C1M = coeffM
coeffM,SEM
# Out:
# (array([32.23028686]), array([7.90287326]))

# %%
# logx = np.log(x[1:-1])
# normy =( y[1:-1]-y[0])/(y[-1]-y[0])
# logy = np.log(normy/(1-normy))

# p, cov = np.polyfit(logx, logy, 1, cov=True)
# var = np.diagonal(cov) #Refer [3]
# SElin = np.sqrt(var) #Refer [4]

# m,b = p


# normyerr = ( YerrL[1:-1]-YerrL[0])/(YerrL[-1]-YerrL[0])
# logyerr = np.power(1/(1-normy),2)*normyerr

# p, SElin

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))

scattersize = 9
cap = 5

ax.errorbar(x , y , yerr= yerr , fmt='',marker='o', markersize=scattersize,capsize = cap,
                              markeredgewidth=4, alpha = 1, ls='')

x0 = np.arange(0, 500, 1)
ax.plot(x0, hillEQ(x0,C1H, C2H), lw=3,ls= '-',alpha = 0.5)
ax.plot(x0, MMEQ(x0,C1M), lw=3,ls= '-',alpha = 0.5)
# x0 = np.arange(0, 250, 1)
# ax.plot(x0, x0*m+b, lw=3,ls= '-',alpha = 0.5)
ax.legend(('Hill','MM'),loc='upper right')
#ax.legend('')
ax.set_xlabel(DCXconc)

# ax.set_xlim(0,100) 
# ax.set_ylim(0,100) 
# ax.set_xticks(np.arange(0, 251, 50))
sns.set_style("ticks")
sns.despine()
ax.spines['left'].set_lw(5)
ax.spines['bottom'].set_lw(5)
ax.tick_params(axis='both', width = 5, length = 15)
sns.set_context("poster", font_scale=1.7, rc={"lines.linewidth":3.0})

plt.tight_layout()


plt.savefig(newmydir/('intensity_mean_test'+date+'.svg'),backend='Cairo')
plt.savefig(newmydir/('intensity_mean_test'+date+'.png'),backend='Cairo')

# %%
scattersize = 9
cap = 5

fig, ax = plt.subplots(1,1,figsize=(2.5,2.5))
ax.errorbar(logx , logy , yerr= 0 , fmt='',marker='o', markersize=scattersize,capsize = cap,
                              markeredgewidth=4, alpha = 1, ls='')

x0 = np.arange(3.3, 4.8, 0.05)
#ax.plot(x0, x0*m+b, lw=3,ls= '-',alpha = 0.5)

# ax.set_ylim(-2.5,2.5)
# ax.set_xlim(3,6)
ax.set_xlabel(r'$\log([DCX])$')
#ax.set_xticks(np.arange(0, 22.1, 2))
#ax.set_yticks(np.arange(0, 150.1, 25))
ax.set_ylabel(r'$\log(\frac{L_N}{1-L_N})$') ]
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_lw(3)
ax.spines['bottom'].set_lw(3)
ax.tick_params(axis='both', width = 3.5, length = 7)

#ax.legend((r'$n=2.94 \pm 0.49$' '\n' r'$R^2 > 0.945$',),loc='lower right',title='Hill Equation')

sns.set_context("poster", font_scale=1, rc={"lines.linewidth":3.0})

#plt.savefig(newmydir/('logexpHillfit_Lifetime_'+date+'.svg'))
