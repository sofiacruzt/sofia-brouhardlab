# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import pandas as pd
from pandas.api.types import CategoricalDtype
import scipy as sp
from pathlib import Path
from tkinter import filedialog
import itertools
from colour import Color
from datetime import date
import statsmodels.api as sm
from statsmodels.stats.weightstats import ztest as ztest
from sklearn.metrics import r2_score as R2S
import cairo

# %% [markdown]
# ## Names and Palette ##

# %%
today = date.today()
print("Today's date:", today)
date = str(today)
date
# Out:
# Today's date: 2023-10-05
# '2023-10-05'

# %%
tubulin = '[Tubulin] ' r'$(\mu M)$'
tub = 'tub'

DCXconc = '[DCX] ' r'$(n M)$'
EBconc = '[EB] ' r'$(n M)$'
DCX = 'DCX'
Type = 'DCX Type'

Concentration = 'Concentration ' r'$(\mu M)$'
Length = 'Length ' r'$(\mu m)$'
Lifetime = 'Lifetime ' r'$(min)$'
GrowthRate = 'Growth Rate ' r'$(\mu m / min)$'
TimeToNucleate = 'Time to Nucleate ' r'$(min)$'
ShrinkageLength = 'Shrink Length ' r'$(\mu m)$'
ShrinkageLifetime = 'Shrink Lifetime ' r'$(min)$'
ShrinkageRate = 'Shrink Rate ' r'$(\mu m / min)$'

# %% [markdown]
# ## Join Data ##

# %%
askdirectory = filedialog.askdirectory() # show an "Open" dialog box and return the path to the selected file
path = Path(askdirectory)

# %%
folders = [x for x in path.iterdir() if x.is_dir()]
folders = [i for i in folders if str(i.stem)[-1] == 'M']
folders
# Out:
# [WindowsPath('D:/Sofia/2023_3fall/2023-09-28_nonSEC-dcxdynWT/CH3_typeWT_DCX60nM'),
#  WindowsPath('D:/Sofia/2023_3fall/2023-09-28_nonSEC-dcxdynWT/CH4_typeWT_DCX230nM'),
#  WindowsPath('D:/Sofia/2023_3fall/2023-09-28_nonSEC-dcxdynWT/CH7_typeWT_DCX115nM'),
#  WindowsPath('D:/Sofia/2023_3fall/2023-09-28_nonSEC-dcxdynWT/CH8_typeWT_DCX30nM')]

# %%
files = []
for k in folders:
    files0 = [x for x in k.iterdir() if x.is_file()]
    files0 = [i for i in files0 if str(i).rfind('Results') != -1 if str(i).rfind('csv') != -1]
    files = files + files0
files
# Out:
# [WindowsPath('D:/Sofia/2023_3fall/2023-09-28_nonSEC-dcxdynWT/CH3_typeWT_DCX60nM/Results.csv'),
#  WindowsPath('D:/Sofia/2023_3fall/2023-09-28_nonSEC-dcxdynWT/CH4_typeWT_DCX230nM/Results.csv'),
#  WindowsPath('D:/Sofia/2023_3fall/2023-09-28_nonSEC-dcxdynWT/CH7_typeWT_DCX115nM/Results.csv'),
#  WindowsPath('D:/Sofia/2023_3fall/2023-09-28_nonSEC-dcxdynWT/CH8_typeWT_DCX30nM/Results.csv')]

# %%
def findmetadata(tag,end,i):
    n = len(tag)
    locstart = str(i).rfind(tag) 
    locend = str(i).find(end, locstart)
    tag0 = str(i)[locstart+n: locend]
    
    return tag0

# %%
dates= []
CH= []
dcx = []
dcxtype= []
for i in files:
    dateloc = str(i).rfind("202")   
    dates0 = str(i)[dateloc : dateloc+10]
    dates = dates + [dates0]

    CH0 = findmetadata("CH",'_',i)
    CH = CH + [CH0]  
    
    type0 = findmetadata("type",'_',i)
    dcxtype = dcxtype + [type0] 
    
    dcx0 = findmetadata("DCX",'nM',i)
    dcx = dcx + [float(dcx0)] 

dates,CH,dcx, dcxtype
# Out:
# (['2023-09-28', '2023-09-28', '2023-09-28', '2023-09-28'],
#  ['3', '4', '7', '8'],
#  [60.0, 230.0, 115.0, 30.0],
#  ['WT', 'WT', 'WT', 'WT'])

# %% [markdown]
# ## Open Data ##

# %%
data = pd.DataFrame(columns=[] , index=[])

for i in np.arange(len(files)):
    data0 = pd.read_csv(files[i], encoding='utf-8',keep_default_na=False)
    data0['Date'] = dates[i]
    data0['CH'] = CH[i]
    data0[DCXconc] = dcx[i]
    data0['Type'] = dcxtype[i]
    
    data = pd.concat([data,data0], ignore_index=True)

data = data.sort_values(by = DCXconc)
data
# Out:
#          Area     Mean  Min  Max    Angle  Length        Date CH  \
# 121  30   120  119.767  108  139  -92.386  24.021  2023-09-28  8
# 93    2   270  129.604  111  144  173.660  54.332  2023-09-28  8
# 94    3   332  121.078  109  143 -141.746  66.219  2023-09-28  8
# 95    4   460  119.337  108  140  151.489  92.179  2023-09-28  8
# 96    5   358  117.827  106  135  -41.035  71.589  2023-09-28  8
# ..   ..   ...      ...  ...  ...      ...     ...         ... ..
# 57   28   360  186.364  157  211  -30.486  71.946  2023-09-28  4
# 58   29   466  183.753  135  214   77.305  93.280  2023-09-28  4
# 59   30   304  180.641  150  216  -66.801  60.926  2023-09-28  4
# 46   17   376  161.314  130  190 -170.036  75.133  2023-09-28  4
# 31    2   493  199.209  141  242  173.307  98.672  2023-09-28  4
#
#      [DCX] $(n M)$ Type
# 121           30.0   WT
# 93            30.0   WT
# 94            30.0   WT
# 95            30.0   WT
# 96            30.0   WT
# ..             ...  ...
# 57           230.0   WT
# 58           230.0   WT
# 59           230.0   WT
# 46           230.0   WT
# 31           230.0   WT
#
# [122 rows x 11 columns]

# %%
newdirectory = str(path.parents[0])+'//Intensity_Data_Sheets'
newmydir = Path(newdirectory)
newmydir.mkdir(exist_ok=True)
newmydir
# Out:
# WindowsPath('D:/Sofia/2023_3fall/Intensity_Data_Sheets')

# %%
name = dates[0]+'_Intensity_analysed-on_'+date +'.csv'
name
# Out:
# '2023-09-28_Intensity_analysed-on_2023-10-05.csv'

# %%
data.to_csv(path/(name), encoding='utf-8', index=False)
data.to_csv(newmydir/(name), encoding='utf-8', index=False)

# %% [markdown]
# ## Plot##

# %%
dcx.sort()

# %%
dcx
# Out:
# [30.0, 60.0, 115.0, 230.0]

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))

ax = sns.boxplot(x= DCXconc, y='Mean', data=data, whis=np.inf, palette='Blues',linewidth=3,native_scale=True)
ax = sns.swarmplot(x=DCXconc, y='Mean', data=data, color=".2", size=12)

#ax.legend( loc = 'lower right')
#ax.legend('')
ax.set_xlabel(DCXconc)

sns.set_style("ticks")
sns.despine()
ax.spines['left'].set_lw(5)
ax.spines['bottom'].set_lw(5)
ax.tick_params(axis='both', width = 5, length = 15)
sns.set_context("poster", font_scale=1.7, rc={"lines.linewidth":3.0})

plt.tight_layout()


#plt.savefig(path/('intensity_'+date_today+'.svg'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-de60ad99d14d> in <module>
#       1 fig, ax = plt.subplots(1,1,figsize=(10,10))
#       2
# ----> 3 ax = sns.boxplot(x= DCXconc, y='Mean', data=data, whis=np.inf, palette='Blues',linewidth=3,native_scale=True)
#       4 ax = sns.swarmplot(x=DCXconc, y='Mean', data=data, color=".2", size=12)
#       5
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2236     kwargs.update(dict(whis=whis))
#    2237
# -> 2238     plotter.plot(ax, kwargs)
#    2239     return ax
#    2240
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     507     def plot(self, ax, boxplot_kws):
#     508         """Make the plot."""
# --> 509         self.draw_boxplot(ax, boxplot_kws)
#     510         self.annotate_axes(ax)
#     511         if self.orient == "h":
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\categorical.py in draw_boxplot(self, ax, kws)
#     444                                          positions=[i],
#     445                                          widths=self.width,
# --> 446                                          **kws)
#     447                 color = self.colors[i]
#     448                 self.restyle_boxplot(artist_dict, color, props)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: boxplot() got an unexpected keyword argument 'native_scale'

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))

ax = sns.boxplot(x= DCXconc, y='Mean', data=data, whis=np.inf, palette='Blues',linewidth=3)
ax = sns.swarmplot(x=DCXconc, y='Mean', data=data, color=".2", size=12)


#ax.legend( loc = 'lower right')
#ax.legend('')
ax.set_xlabel(DCXconc)

sns.set_style("ticks")
sns.despine()
ax.spines['left'].set_lw(5)
ax.spines['bottom'].set_lw(5)
ax.tick_params(axis='both', width = 5, length = 15)
sns.set_context("poster", font_scale=1.7, rc={"lines.linewidth":3.0})

plt.tight_layout()


#plt.savefig(path/('intensity_'+date_today+'.svg'))
# Out:
# C:\Users\Brouhard Lab\AppData\Roaming\Python\Python37\site-packages\seaborn\categorical.py:1296: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
