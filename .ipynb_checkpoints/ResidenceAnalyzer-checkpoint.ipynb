# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
from pathlib import Path
from read_roi import read_roi_zip
from collections import OrderedDict, Counter
import math
import PIL
from PIL import Image
from PIL.TiffTags import TAGS
import tkinter as tk
from tkinter import filedialog
import seaborn as sns
from pandas.api.types import CategoricalDtype
import scipy as sp
import tkinter as tk
from tkinter import filedialog
import itertools
from colour import Color

# %%
askfile = filedialog.askopenfile() # show an "Open" dialog box and select the file

# %%
data = pd.read_csv(askfile, encoding='utf-8')
data
# Out:
#              Label  TRACK_ID  NUMBER_SPOTS  NUMBER_GAPS  LONGEST_GAP  \
# 0      Track_11091         0            10            1            1
# 1      Track_11092         1            81            5            3
# 2      Track_11093         2            96            4            3
# 3      Track_11094         3             9            0            0
# 4      Track_11095         4             3            0            0
# ...            ...       ...           ...          ...          ...
# 11951  Track_23042     11951             2            0            0
# 11952  Track_23043     11952             2            0            0
# 11953  Track_23044     11953             2            0            0
# 11954  Track_23045     11954             2            0            0
# 11955  Track_23046     11955             2            0            0
#
#        NUMBER_SPLITS  NUMBER_MERGES  NUMBER_COMPLEX  TRACK_DURATION  \
# 0                  0              0               0              10
# 1                  0              0               0              88
# 2                  0              0               0             101
# 3                  0              0               0               8
# 4                  0              0               0               2
# ...              ...            ...             ...             ...
# 11951              0              0               0               1
# 11952              0              0               0               1
# 11953              0              0               0               1
# 11954              0              0               0               1
# 11955              0              0               0               1
#
#        TRACK_START  ...  TRACK_MEAN_SPEED  TRACK_MAX_SPEED  TRACK_MIN_SPEED  \
# 0                0  ...             0.837            2.269            0.182
# 1                0  ...             0.447            1.114            0.031
# 2                0  ...             0.490            1.221            0.042
# 3                0  ...             0.971            1.981            0.361
# 4                0  ...             0.550            0.783            0.317
# ...            ...  ...               ...              ...              ...
# 11951          498  ...             0.374            0.374            0.374
# 11952          498  ...             1.230            1.230            1.230
# 11953          498  ...             1.007            1.007            1.007
# 11954          498  ...             0.579            0.579            0.579
# 11955          498  ...             1.370            1.370            1.370
#
#        TRACK_MEDIAN_SPEED  TRACK_STD_SPEED  TRACK_MEAN_QUALITY  \
# 0                   0.469            0.703               8.769
# 1                   0.400            0.267              12.962
# 2                   0.457            0.281               9.368
# 3                   0.984            0.524               9.899
# 4                   0.783            0.330               8.785
# ...                   ...              ...                 ...
# 11951               0.374              NaN               7.542
# 11952               1.230              NaN               6.506
# 11953               1.007              NaN               7.650
# 11954               0.579              NaN               8.839
# 11955               1.370              NaN               6.957
#
#        TRACK_MAX_QUALITY  TRACK_MIN_QUALITY  TRACK_MEDIAN_QUALITY  \
# 0                 10.486              6.618                 8.981
# 1                 28.911              6.174                11.353
# 2                 15.674              6.237                 9.139
# 3                 12.381              6.133                 9.857
# 4                  9.909              7.341                 9.104
# ...                  ...                ...                   ...
# 11951              7.763              7.321                 7.763
# 11952              6.957              6.056                 6.957
# 11953              8.211              7.090                 8.211
# 11954              9.520              8.159                 9.520
# 11955              6.972              6.943                 6.972
#
#        TRACK_STD_QUALITY
# 0                  1.333
# 1                  4.745
# 2                  2.056
# 3                  2.213
# 4                  1.072
# ...                  ...
# 11951              0.221
# 11952              0.450
# 11953              0.561
# 11954              0.680
# 11955              0.015
#
# [11956 rows x 26 columns]

# %%
x=data['TRACK_X_LOCATION']
y=data['TRACK_Y_LOCATION']
scattersize = 1
cap = 5
fig, ax = plt.subplots(1,1,figsize=(7.45*1.5,7.75*1.5))
ax.scatter(x , y , s = scattersize)

# %%
y=data['TRACK_MEDIAN_QUALITY']
scattersize = 1
cap = 5
fig, ax = plt.subplots(1,1,figsize=(7.45,7.75))
ax.hist(y, bins=np.arange(0, 20 + 0.11, 0.11), density=True);

# %%
data0 = data[(data['TRACK_START']>5) & (data['TRACK_STOP']<495) & (data['TRACK_DURATION']>5)& (data['TRACK_MEDIAN_QUALITY']>7.5)]
data0
# Out:
#              Label  TRACK_ID  NUMBER_SPOTS  NUMBER_GAPS  LONGEST_GAP  \
# 586    Track_11677       586            11            1            2
# 599    Track_11690       599             4            1            4
# 621    Track_11712       621            13            0            0
# 633    Track_11724       633            12            0            0
# 672    Track_11763       672            36            6            3
# ...            ...       ...           ...          ...          ...
# 11752  Track_22843     11752             7            0            0
# 11754  Track_22845     11754             6            1            2
# 11757  Track_22848     11757             8            1            1
# 11766  Track_22857     11766             9            0            0
# 11787  Track_22878     11787             7            0            0
#
#        NUMBER_SPLITS  NUMBER_MERGES  NUMBER_COMPLEX  TRACK_DURATION  \
# 586                0              0               0              12
# 599                0              0               0               7
# 621                0              0               0              12
# 633                0              0               0              11
# 672                0              0               0              50
# ...              ...            ...             ...             ...
# 11752              0              0               0               6
# 11754              0              0               0               7
# 11757              0              0               0               8
# 11766              0              0               0               8
# 11787              0              0               0               6
#
#        TRACK_START  ...  TRACK_MEAN_SPEED  TRACK_MAX_SPEED  TRACK_MIN_SPEED  \
# 586              6  ...             0.509            1.114            0.058
# 599              6  ...             0.418            0.600            0.102
# 621              6  ...             0.636            1.097            0.303
# 633              6  ...             0.318            0.510            0.116
# 672              7  ...             0.525            1.432            0.065
# ...            ...  ...               ...              ...              ...
# 11752          485  ...             0.706            1.267            0.481
# 11754          485  ...             0.943            1.721            0.382
# 11757          485  ...             0.554            0.762            0.146
# 11766          485  ...             0.594            1.188            0.375
# 11787          486  ...             0.545            0.973            0.132
#
#        TRACK_MEDIAN_SPEED  TRACK_STD_SPEED  TRACK_MEAN_QUALITY  \
# 586                 0.506            0.293               9.571
# 599                 0.552            0.275               7.289
# 621                 0.680            0.254               8.814
# 633                 0.276            0.127               9.527
# 672                 0.451            0.339               7.617
# ...                   ...              ...                 ...
# 11752               0.576            0.326               8.585
# 11754               0.785            0.587               8.382
# 11757               0.613            0.210               8.137
# 11766               0.540            0.282              10.339
# 11787               0.637            0.287               9.652
#
#        TRACK_MAX_QUALITY  TRACK_MIN_QUALITY  TRACK_MEDIAN_QUALITY  \
# 586               14.137              6.496                 8.778
# 599                7.623              6.350                 7.618
# 621               13.313              6.540                 8.230
# 633               12.126              6.396                 9.604
# 672               10.095              6.031                 7.616
# ...                  ...                ...                   ...
# 11752             11.250              6.620                 8.675
# 11754              9.827              6.340                 8.610
# 11757             11.097              6.461                 8.672
# 11766             17.114              6.480                 9.629
# 11787             11.557              7.266                10.099
#
#        TRACK_STD_QUALITY
# 586                1.938
# 599                0.543
# 621                2.080
# 633                1.565
# 672                1.081
# ...                  ...
# 11752              1.457
# 11754              1.142
# 11757              1.606
# 11766              3.079
# 11787              1.611
#
# [1846 rows x 26 columns]

# %%
x=data0['TRACK_X_LOCATION']
y=data0['TRACK_Y_LOCATION']
fig, ax = plt.subplots(1,1,figsize=(7.45*1.5,7.75*1.5))
ax.scatter(x , y , s = scattersize)

# %%
def filter_neighbors(data0,R1,N,R2,C):
    xy = data0[['TRACK_X_LOCATION','TRACK_Y_LOCATION']]
    for i in list(xy.index): #
        
        xyvalue = xy.loc[i].values
        xvalue = xyvalue[0]
        yvalue = xyvalue[1]
        
        R = R1
        square1 = xy[(xy['TRACK_X_LOCATION']<(xvalue+R)) & (xy['TRACK_X_LOCATION']>(xvalue-R)) & (xy['TRACK_Y_LOCATION']<(yvalue+R)) & (xy['TRACK_Y_LOCATION']>(yvalue-R))]
        
        R = R2
        square2 = xy[(xy['TRACK_X_LOCATION']<(xvalue+R)) & (xy['TRACK_X_LOCATION']>(xvalue-R)) & (xy['TRACK_Y_LOCATION']<(yvalue+R)) & (xy['TRACK_Y_LOCATION']>(yvalue-R))]
        
        column_1 = square2['TRACK_X_LOCATION']
        column_2 = square2['TRACK_Y_LOCATION']
        correlation = column_1.corr(column_2)
        
        if (len(square1) < N) | (abs(correlation) < C):
            try:
                data0 = data0.drop(square1.index)
                data0 = data0.drop(square2.index)
            except KeyError:
                 continue

    return data0

# %%
data1 = filter_neighbors(data0,15,5,7,0.01)

x=data1['TRACK_X_LOCATION']
y=data1['TRACK_Y_LOCATION']
fig, ax = plt.subplots(1,1,figsize=(7.45*1.5,7.75*1.5))
ax.scatter(x , y , s = scattersize)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
def exponential(x, scale):
    return ((np.exp(-(x)/scale) )/(scale))
def equation_fit(track_duration):
    
    equation = exponential
        
    results = pd.DataFrame(columns=[] , index=[])
    
    n, bins, patches = ax.hist(track_duration, bins=np.arange(0, 150 + 1, 1), density=True);
                
    coeff, var_matrix = sp.optimize.curve_fit(equation,bins[:-1],n)

    variance = np.diagonal(var_matrix) #Refer [3]
    SE = np.sqrt(variance) #Refer [4]

            #======Making a data frame========
    results0 = pd.DataFrame(columns=[] , index=[])
    
    for k in np.arange(0,len(coeff)):
        header = [np.array(['Exponential']),np.array(['Coefficient '+ str(k)])]
        r0 = pd.DataFrame([coeff[k],SE[k]], index=(['Value','SE']),columns= header)
        results0 = pd.concat([results0, r0], axis=1, sort=False)

    results = pd.concat([results, results0], sort=False)

    return results

# %%
track_duration=data1['TRACK_DURATION']*0.1 #times 100ms
EqFit = equation_fit(track_duration)
scale = EqFit['Exponential']['Coefficient 0'].loc['Value']
#x0 = EqFit['Exponential']['Coefficient 1'].loc['Value']
EqFit
# Out:
#         Exponential
#       Coefficient 0
# Value      2.510594
# SE         0.060855

# %%
x = np.arange(0, 20 + 0.1, 0.1)
fig, ax = plt.subplots(1,1,figsize=(7.45,7.75))
ax.hist(track_duration, bins=np.arange(0, 20 + 0.1, 0.1), density=True);
ax.plot(x, exponential(x, scale), lw=4);
ax.set_xlabel('Time (s)')
ax.set_ylabel('Probability')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_lw(3)
ax.spines['bottom'].set_lw(3)
sns.set_context("poster", font_scale=1, rc={"lines.linewidth":3.0})
plt.tight_layout()

# %%
track_duration
# Out:
# 621      1.2
# 672      5.0
# 675      2.4
# 682      1.4
# 683      5.9
#         ...
# 11704    0.7
# 11740    1.0
# 11752    0.6
# 11766    0.8
# 11787    0.6
# Name: TRACK_DURATION, Length: 1293, dtype: float64
