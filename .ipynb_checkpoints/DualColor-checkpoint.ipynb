# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
from pathlib import Path
from read_roi import read_roi_zip
from collections import OrderedDict, Counter
import math
import PIL
from PIL import Image
from PIL.TiffTags import TAGS
import tkinter as tk
from tkinter import filedialog
import seaborn as sns
from pandas.api.types import CategoricalDtype
import itertools
from colour import Color
from datetime import date

# %%
today = date.today()
print("Today's date:", today)
date_today = str(today)
date_today
# Out:
# Today's date: 2021-11-26
# '2021-11-26'

# %%
askdirectory = filedialog.askdirectory() # show an "Open" dialog box and return the path to the selected file
path = Path(askdirectory)
path
# Out:
# WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor')

# %%
parents = [x for x in path.iterdir() if x.is_dir()]
parents
# Out:
# [WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-15_dualcolor_lowbindigtips'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-17_dualcolor_wt_r303x'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-22_dualcolor_freshtaxol'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/mt-area')]

# %%
folders = []
for j in parents:
    folders0 = [x for x in j.iterdir() if x.is_dir()]
    folders0 = [i for i in folders0 if (str(i)[-3:] == 'yes') == True]
    folders =  folders + folders0

folders
# Out:
# [WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-17_dualcolor_wt_r303x/CH3_DCXGFP0.5nM_typeWT_DCXRFP9.5nM_freshtaxol-yes'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH1_DCXGFP0.5nM_typeR303X_DCXRFP9.5nM-yes'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH2_DCXGFP0.5nM_typeR303X_DCXRFP8.5nM-yes'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeWT_DCXRFP8.5nM-yes'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-22_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeWT_DCXRFP6.5nM-yes'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-22_dualcolor_freshtaxol/CH5_DCXGFP0.5nM_typeR303X_DCXRFP6.5nM-yes'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH1_DCXGFP0.5nM_typeWT_DCXRFP4.5nM-yes'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH2_DCXGFP0.5nM_typeR303X_DCXRFP4.5nM-yes'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH3_DCXGFP0.5nM_typeWT_DCXRFP2.5nM-yes'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeR303X_DCXRFP2.5nM-yes')]

# %%
files = []
for j in range(0,len(folders)):  
    resultfolder = folders[j]/'results'
    files0 = [x for x in resultfolder.iterdir() if x.is_file()]
    files0 = [i for i in files0 if str(i).rfind('Results') != -1]
    files = files + files0
files
# Out:
# [WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-17_dualcolor_wt_r303x/CH3_DCXGFP0.5nM_typeWT_DCXRFP9.5nM_freshtaxol-yes/results/2_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-17_dualcolor_wt_r303x/CH3_DCXGFP0.5nM_typeWT_DCXRFP9.5nM_freshtaxol-yes/results/3_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-17_dualcolor_wt_r303x/CH3_DCXGFP0.5nM_typeWT_DCXRFP9.5nM_freshtaxol-yes/results/4_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-17_dualcolor_wt_r303x/CH3_DCXGFP0.5nM_typeWT_DCXRFP9.5nM_freshtaxol-yes/results/5_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-17_dualcolor_wt_r303x/CH3_DCXGFP0.5nM_typeWT_DCXRFP9.5nM_freshtaxol-yes/results/6_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH1_DCXGFP0.5nM_typeR303X_DCXRFP9.5nM-yes/results/1_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH1_DCXGFP0.5nM_typeR303X_DCXRFP9.5nM-yes/results/3_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH1_DCXGFP0.5nM_typeR303X_DCXRFP9.5nM-yes/results/4_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH1_DCXGFP0.5nM_typeR303X_DCXRFP9.5nM-yes/results/5_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH1_DCXGFP0.5nM_typeR303X_DCXRFP9.5nM-yes/results/7_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH2_DCXGFP0.5nM_typeR303X_DCXRFP8.5nM-yes/results/1_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH2_DCXGFP0.5nM_typeR303X_DCXRFP8.5nM-yes/results/3_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH2_DCXGFP0.5nM_typeR303X_DCXRFP8.5nM-yes/results/5_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH2_DCXGFP0.5nM_typeR303X_DCXRFP8.5nM-yes/results/7_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH2_DCXGFP0.5nM_typeR303X_DCXRFP8.5nM-yes/results/Result of _Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeWT_DCXRFP8.5nM-yes/results/1_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeWT_DCXRFP8.5nM-yes/results/3_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeWT_DCXRFP8.5nM-yes/results/5_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeWT_DCXRFP8.5nM-yes/results/6_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-18_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeWT_DCXRFP8.5nM-yes/results/7_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-22_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeWT_DCXRFP6.5nM-yes/results/1_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-22_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeWT_DCXRFP6.5nM-yes/results/3_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-22_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeWT_DCXRFP6.5nM-yes/results/5_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-22_dualcolor_freshtaxol/CH5_DCXGFP0.5nM_typeR303X_DCXRFP6.5nM-yes/results/3_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-22_dualcolor_freshtaxol/CH5_DCXGFP0.5nM_typeR303X_DCXRFP6.5nM-yes/results/4_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-22_dualcolor_freshtaxol/CH5_DCXGFP0.5nM_typeR303X_DCXRFP6.5nM-yes/results/5_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH1_DCXGFP0.5nM_typeWT_DCXRFP4.5nM-yes/results/3_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH1_DCXGFP0.5nM_typeWT_DCXRFP4.5nM-yes/results/4_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH1_DCXGFP0.5nM_typeWT_DCXRFP4.5nM-yes/results/5_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH2_DCXGFP0.5nM_typeR303X_DCXRFP4.5nM-yes/results/1_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH2_DCXGFP0.5nM_typeR303X_DCXRFP4.5nM-yes/results/2_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH2_DCXGFP0.5nM_typeR303X_DCXRFP4.5nM-yes/results/3_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH3_DCXGFP0.5nM_typeWT_DCXRFP2.5nM-yes/results/3_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH3_DCXGFP0.5nM_typeWT_DCXRFP2.5nM-yes/results/5_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH3_DCXGFP0.5nM_typeWT_DCXRFP2.5nM-yes/results/7_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeR303X_DCXRFP2.5nM-yes/results/1_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeR303X_DCXRFP2.5nM-yes/results/3_Results.csv'),
#  WindowsPath('C:/Users/Brouhard Lab/Dropbox/DCX/DualColor/2021-11-25_dualcolor_freshtaxol/CH4_DCXGFP0.5nM_typeR303X_DCXRFP2.5nM-yes/results/7_Results.csv')]

# %%
ch = []
conc_DCXRFP = []
conc_DCXGFP = []
DCX_type = []
dates = []

for i in files:
    CHloc = str(i).find('CH')
    DCXRFPloc = str(i).rfind('RFP')
    DCXGFPloc = str(i).rfind('GFP')
    dcxtype = str(i).find('type')
    ch = ch + [str(i)[CHloc+2:CHloc+3]]
    conc_DCXRFP = conc_DCXRFP + [(str(i)[DCXRFPloc+3:DCXRFPloc+6])]
    conc_DCXGFP = conc_DCXGFP + [(str(i)[DCXGFPloc+3:DCXGFPloc+6])]
    DCX_type = DCX_type + [(str(i)[dcxtype+4:DCXRFPloc-4])]
    
    dateloc = str(i).find("202")
    dates = dates + [str(i)[dateloc : dateloc+10]]

    conc_DCXGFP =  [float(i) for i in conc_DCXGFP]
    conc_DCXRFP =  [float(i) for i in conc_DCXRFP]

# %%
dcxgfp_conc = '[GFP-DCX](nM)'
dcxrfp_conc = '[RFP-DCX](nM)'
corr_gfp = 'GFPxRFP Correlation %'
area_rfp = 'RFP Area %'
Type = 'Type'

# %%
metadf = pd.DataFrame({'Date': dates,'CH': ch,'Type': DCX_type,
                   dcxgfp_conc: conc_DCXGFP,
                   dcxrfp_conc: conc_DCXRFP})

# %%
df = pd.DataFrame(columns=['GFP','RFP','Cy5','GFPxRFP'])
for i in files:
    resultcsv = pd.read_csv(i, encoding='utf-8')
    arr = resultcsv['Mean'].values
    df = df.append(pd.DataFrame(arr.reshape(1,-1), columns=list(df)), ignore_index=True)

# %%
result = pd.concat([metadf, df], axis=1)

# %%
result[corr_gfp] = df['GFPxRFP'] / df['GFP'] * 100
result[area_rfp] = df['RFP'] / df['Cy5'] * 100

# %%
Type_order = ['WT','R303X']
category_Type = CategoricalDtype(Type_order, ordered=True,) #order mutants
result[Type] = result[Type].astype(category_Type)
result = result.sort_values(by=[Type, dcxrfp_conc])

# %%
result.to_csv(path/('correlation-analysis_'+date_today +'.csv'), encoding='utf-8', index=False)
result
# Out:
#           Date CH   Type  [GFP-DCX](nM)  [RFP-DCX](nM)    GFP    RFP     Cy5  \
# 32  2021-11-25  3     WT            0.5            2.5  1.053  1.488   5.803
# 33  2021-11-25  3     WT            0.5            2.5  1.452  1.694   4.873
# 34  2021-11-25  3     WT            0.5            2.5  2.090  2.809   8.116
# 26  2021-11-25  1     WT            0.5            4.5  3.063  3.598   6.250
# 27  2021-11-25  1     WT            0.5            4.5  4.154  4.708   9.407
# 28  2021-11-25  1     WT            0.5            4.5  3.277  3.981   9.104
# 20  2021-11-22  4     WT            0.5            6.5  3.684  4.892   9.832
# 21  2021-11-22  4     WT            0.5            6.5  3.253  4.702   9.679
# 22  2021-11-22  4     WT            0.5            6.5  1.718  3.008   7.829
# 15  2021-11-18  4     WT            0.5            8.5  2.570  4.526  12.371
# 16  2021-11-18  4     WT            0.5            8.5  2.386  3.953   9.276
# 17  2021-11-18  4     WT            0.5            8.5  2.602  4.062   9.502
# 18  2021-11-18  4     WT            0.5            8.5  3.511  6.304  14.366
# 19  2021-11-18  4     WT            0.5            8.5  2.559  4.649  11.542
# 0   2021-11-17  3     WT            0.5            9.5  2.294  3.096   4.686
# 1   2021-11-17  3     WT            0.5            9.5  1.894  2.298   3.122
# 2   2021-11-17  3     WT            0.5            9.5  2.520  3.307   4.798
# 3   2021-11-17  3     WT            0.5            9.5  3.391  4.157   6.227
# 4   2021-11-17  3     WT            0.5            9.5  3.309  4.431   6.330
# 35  2021-11-25  4  R303X            0.5            2.5  3.378  4.960  11.368
# 36  2021-11-25  4  R303X            0.5            2.5  1.218  1.961   7.103
# 37  2021-11-25  4  R303X            0.5            2.5  1.521  2.376   7.345
# 29  2021-11-25  2  R303X            0.5            4.5  1.966  4.598  11.243
# 30  2021-11-25  2  R303X            0.5            4.5  2.554  2.965   8.640
# 31  2021-11-25  2  R303X            0.5            4.5  2.692  3.139   7.579
# 23  2021-11-22  5  R303X            0.5            6.5  2.811  4.219   7.503
# 24  2021-11-22  5  R303X            0.5            6.5  2.039  3.967   6.787
# 25  2021-11-22  5  R303X            0.5            6.5  1.642  2.057   3.597
# 10  2021-11-18  2  R303X            0.5            8.5  3.447  4.545   9.142
# 11  2021-11-18  2  R303X            0.5            8.5  1.408  2.714   5.895
# 12  2021-11-18  2  R303X            0.5            8.5  4.450  5.609  13.574
# 13  2021-11-18  2  R303X            0.5            8.5  3.547  5.417  10.974
# 14  2021-11-18  2  R303X            0.5            8.5  3.016  3.637   8.746
# 5   2021-11-18  1  R303X            0.5            9.5  2.952  4.801   7.649
# 6   2021-11-18  1  R303X            0.5            9.5  2.576  3.775   5.320
# 7   2021-11-18  1  R303X            0.5            9.5  2.942  3.838   5.993
# 8   2021-11-18  1  R303X            0.5            9.5  3.255  3.967   6.585
# 9   2021-11-18  1  R303X            0.5            9.5  4.072  5.755   8.737
#
#     GFPxRFP  GFPxRFP Correlation %  RFP Area %
# 32    0.747              70.940171   25.641909
# 33    1.070              73.691460   34.762980
# 34    1.628              77.894737   34.610646
# 26    2.415              78.844270   57.568000
# 27    3.357              80.813674   50.047837
# 28    2.552              77.876106   43.728032
# 20    2.691              73.045603   49.755899
# 21    2.461              75.653243   48.579399
# 22    1.294              75.320140   38.421254
# 15    1.821              70.856031   36.585563
# 16    1.933              81.014250   42.615351
# 17    2.095              80.514988   42.748895
# 18    2.894              82.426659   43.881387
# 19    1.944              75.967175   40.278981
# 0     2.139              93.243243   66.069142
# 1     1.781              94.033791   73.606662
# 2     2.325              92.261905   68.924552
# 3     3.107              91.624889   66.757668
# 4     3.103              93.774554   70.000000
# 35    2.125              62.907046   43.631246
# 36    0.842              69.129721   27.608053
# 37    1.031              67.784352   32.348536
# 29    1.421              72.278739   40.896558
# 30    1.751              68.559123   34.317130
# 31    1.845              68.536404   41.417073
# 23    2.246              79.900391   56.230841
# 24    1.806              88.572830   58.449978
# 25    1.337              81.425091   57.186544
# 10    2.328              67.536989   49.715598
# 11    1.150              81.676136   46.039016
# 12    2.933              65.910112   41.321644
# 13    2.737              77.163800   49.362129
# 14    2.148              71.220159   41.584724
# 5     2.466              83.536585   62.766375
# 6     2.352              91.304348   70.958647
# 7     2.578              87.627464   64.041382
# 8     2.725              83.717358   60.242976
# 9     3.637              89.317289   65.869292

# %%
fig, axes = plt.subplots(1,2,figsize=(11,6))
sns.set_style("ticks")

corr = sns.swarmplot(ax=axes[0],x=Type, y=corr_gfp, hue=dcxrfp_conc, data=result)
area = sns.swarmplot(ax=axes[1],x=Type, y=area_rfp, hue=dcxrfp_conc, data=result)

corr.set(ylim=(0, 100))
area.set(ylim=(0, 100))

area.legend([],[], frameon=False)

sns.despine()
sns.set_context("poster", font_scale=1, rc={"lines.linewidth":3.0})
plt.tight_layout()

plt.savefig(path/('correlation_area_'+date_today+'.pdf'))

# %%
fig, axes = plt.subplots(1,2,figsize=(11,6))
sns.set_style("ticks")

corr = sns.swarmplot(ax=axes[0],x=dcxrfp_conc, y=corr_gfp, hue=Type, data=result)
area = sns.swarmplot(ax=axes[1],x=dcxrfp_conc, y=area_rfp, hue=Type, data=result)

corr.set(ylim=(0, 100))
area.set(ylim=(0, 100))

area.legend([],[], frameon=False)

sns.despine()
sns.set_context("poster", font_scale=1, rc={"lines.linewidth":3.0})
plt.tight_layout()

plt.savefig(path/('correlation_area_hueType'+date_today+'.pdf'))

# %%
dcxgfp_conc = '[GFP-DCX](nM)'
dcxrfp_conc = '[RFP-DCX](nM)'
corr_gfp = 'GFPxRFP Correlation %'
area_rfp = 'RFP Area %'
Type = 'Type'

# %%
scattersize = 12
cap = 5

fig, ax = plt.subplots(1,1,figsize=(6.25,6))
#     plt.suptitle('Fitted pooled data', fontsize=30)

count = 0
for dcxtype in result[Type].unique(): #data[Type].unique()

    x = result[(result[Type]== dcxtype)][area_rfp]

    y = result[(result[Type]== dcxtype)][corr_gfp]

    ax.scatter(x , y,s= scattersize)
    count += 1

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_lw(3)
ax.spines['bottom'].set_lw(3)
ax.tick_params(axis='both', width = 3.5, length = 7)
ax.set_ylim(-0.015,100)
ax.set_xlim(-0.015,100)
ax.set_xlabel( area_rfp)
ax.xaxis.set_ticks(np.arange(0, 101, 20))

#ax.set_title('Rescue')
ax.set_ylabel(corr_gfp)


#ax.legend((Type_order),loc='upper left',title='DCX Type')
#fig.suptitle('[Tubulin] ' r'$= 6 \mu M$')
plt.tight_layout()
